# %% [markdown]
# <a href="https://colab.research.google.com/github/peramsrinivasareddy/FMML-LABS-22B21A4330/blob/main/FMML_Course_Topic_8_Lab_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Bayesian Machine Learning: Lab 3 - Applying Bayes Classifiers

# %% [markdown]
# Lab by V Vijay Vignesh
#
# vijay.vignesh@research.iiit.ac.in

# %%
import os
import json
import re

import numpy as np
import pandas as pd

from matplotlib import pyplot as plt
import seaborn as sns
import plotly.express as px
import plotly.graph_objects as pg

import tensorflow as tf
import tensorflow_probability as tfp

# %%
# !wget https://raw.githubusercontent.com/Foundations-in-Modern-Machine-Learning/course-contents/main/Bayesian/data/arxiv-paper-data.json
plt.style.use('ggplot')
# Out:
# --2024-05-24 04:57:00--  https://raw.githubusercontent.com/Foundations-in-Modern-Machine-Learning/course-contents/main/Bayesian/data/arxiv-paper-data.json
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.111.133, 185.199.110.133, 185.199.108.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.111.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 72422946 (69M) [text/plain]
# Saving to: ‘arxiv-paper-data.json.1’
#
# arxiv-paper-data.js 100%[===================>]  69.07M   224MB/s    in 0.3s
#
# 2024-05-24 04:57:00 (224 MB/s) - ‘arxiv-paper-data.json.1’ saved [72422946/72422946]

# %% [markdown]
# Let's make a few assumptions to come up with our first general model for classification:
# * The different features contribute equally to the result
# * The features are independent

# %% [markdown]
# ## Bayes Classifiers in Scikit Learn

# %% [markdown]
# ### Simple 1-D Classfication using Naive Bayes in Continuous Space

# %%
fig, ax = plt.subplots(figsize=(18, 8))
x1 = np.random.normal(1.0, 0.3, size=5000)
x2 = np.random.normal(0.0, 0.3, size=50000)
x = np.concatenate([x1, x2])
y = np.concatenate([np.zeros(len(x1)), np.ones(len(x2))])
sns.histplot(x1, color='blue', alpha=0.5, ax=ax)
sns.histplot(x2, color='red', alpha=0.5, ax=ax)
ax.fill_between(np.linspace(-1.0, 0.7, 100), 0, 1800,  color='r', alpha=0.1)
ax.fill_between(np.linspace(0.7, 2.0, 100), 0, 1800,  color='b', alpha=0.1)
ax.vlines(0.5, 0, 1750, color="k", linestyles="--", lw=3)
ax.vlines(0.7, 0, 1750, color="g", linestyles="--", lw=3)
ax.scatter(x1, [np.random.randint(2000, 3000) for _ in x1], color='b', s=1)
ax.scatter(x2, [np.random.randint(2000, 3000) for _ in x2], color='r', s=1)
ax.set_xlim(-1.0, 2.0)
ax.set_ylim(0, 3200)
plt.show()

# %%
from sklearn.naive_bayes import GaussianNB
gnb = GaussianNB()
x_reshaped = x.reshape(1, -1)
print(x_reshaped.shape)
# Out:
# (1, 55000)

# %% [markdown]
# ## Gaussian Bayes Predictor on Predicting Flowers

# %% [markdown]
# ### Predictors in Scikit Learn

# %%
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
from sklearn.naive_bayes import GaussianNB

X, y = load_iris(return_X_y=True)
X = X[:, [2, 3]]
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.5, random_state=0)
gnb = GaussianNB()
gnb.fit(X_train, y_train)
# Out:
# GaussianNB()

# %%
plt.figure(figsize=(20, 10))
color_scheme = ['red', 'green', 'blue']
plt.scatter(X_train[:, 0], X_train[:, 1], c=[color_scheme[idx] for idx in y_train])
plt.show()

# %% [markdown]
# ### Visualizing the Decision Surface

# %%
plt.figure(figsize=(20, 10))
X1_scan, X2_scan = np.meshgrid(np.linspace(0.5, 7.5, 250), np.linspace(0.0, 3.0, 250))
X_scan = np.stack([np.reshape(X1_scan, -1), np.reshape(X2_scan, -1)], axis=-1)
predictions = gnb.predict(X_scan)
color_map = ['r', 'g', 'b']
plt.scatter(x=X_test[:, 0], y=X_test[:, 1], c=[color_map[x] for x in y_test])
sns.kdeplot(x=X_scan[:, 0], y=X_scan[:, 1], hue=[color_map[x] for x in predictions], fill=False)
plt.show()

# %% [markdown]
# ## Bayes on Text - Classifying papers at Arxiv

# %% [markdown]
# ### Data Cleaning and Preprocessing

# %%
arxiv_df = pd.read_json(open("arxiv-paper-data.json", 'r'))
arxiv_df["tag"] = arxiv_df["tag"].apply(lambda x: json.loads(x.replace("\'", "\"").replace("None", "\"None\""))[0]['term'].split('.')[0])
arxiv_df["tag"] = arxiv_df["tag"].apply(lambda x: 'physics' if x in ['physics', 'quant-ph', 'astro-ph', 'hep-ex', 'hep-ph', 'hep-lat', 'hep-th', 'nucl-th'] else x)
arxiv_df = arxiv_df.drop(["day", "month", "link", "author"], axis=1)

# %%
SAMPLES_COMP = 3500 #@param {type: "slider", min: 1000, max: 4500}
SAMPLES_STAT = 2500 #@param {type: "slider", min: 1000, max: 4500}
WORD_COUNT_THRESHOLD = 1  #@param {type: "slider", min: 1, max: 500}
WORD_LENGTH_THRESHOLD = 8  #@param {type: "slider", min: 4, max: 20}

# %%
df = pd.concat([arxiv_df[arxiv_df['tag'] == 'cs'].sample(SAMPLES_COMP, replace=False),
                arxiv_df[arxiv_df['tag'] == 'stat'].sample(SAMPLES_STAT, replace=False)]).sample(frac=1)
df['keywords'] = df.apply(lambda x: [word.lower() for word in re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', x.summary + ' ' + x.title)).split()
                                     if len(word) > WORD_LENGTH_THRESHOLD and not re.search('(\d|\(|\))', word)], axis=1)
train_df, test_df = df.iloc[:int(len(df) * 0.8)], df.iloc[int(len(df) * 0.8):]

train_df
# Out:
#                  id                                            summary   tag  \
# 38366  1702.06875v1  Mental health forums are online communities wh...    cs
# 23424   1204.1611v1  Gender is an important demographic attribute o...    cs
# 33451  1604.03277v1  The most common representation in evolutionary...    cs
# 12625  1803.07200v1  This paper presents a new approach for trainin...    cs
# 5926    1302.5125v1  One of the fundamental problems in machine lea...  stat
# ...             ...                                                ...   ...
# 3689   1510.04163v1  We develop a parallel variational inference (V...  stat
# 11206  1501.05194v2  The use of mutual information as a similarity ...  stat
# 17995  cs/0003037v1  In this paper, we outline the prototype of an ...    cs
# 35916   0710.1924v1  Current methods of routing are based on networ...    cs
# 33368   1107.3498v1  Slow self-avoiding adaptive walks by an infini...    cs
#
#                                                    title  year  \
# 38366  Triaging Content Severity in Online Mental Hea...  2017
# 23424    Vision-based Human Gender Recognition: A Survey  2012
# 33451  The Right Mutation Strength for Multi-Valued D...  2016
# 12625  Training Recurrent Neural Networks as a Constr...  2018
# 5926   High-Dimensional Probability Estimation with D...  2013
# ...                                                  ...   ...
# 3689   Embarrassingly Parallel Variational Inference ...  2015
# 11206  A Bayesian alternative to mutual information f...  2015
# 17995  QUIP - A Tool for Computing Nonmonotonic Reaso...  2000
# 35916  A Heuristic Routing Mechanism Using a New Addr...  2007
# 33368  What can we learn from slow self-avoiding adap...  2011
#
#                                                 keywords
# 38366  [communities, moderators, indicating, attempte...
# 23424  [important, demographic, attribute, recognitio...
# 33451  [representation, evolutionary, computation, va...
# 12625  [artificial, techniques, constraint, satisfact...
# 5926   [fundamental, estimation, probability, distrib...
# ...                                                  ...
# 3689   [variational, inference, procedure, distribute...
# 11206  [information, similarity, agglomerative, hiera...
# 17995  [prototype, automated, inference, implementati...
# 35916  [information, protocols, determine, according,...
# 33368  [algorithm, themselves, conducted, examination...
#
# [4800 rows x 6 columns]

# %%
df['keywords']
# Out:
# 38366    [communities, moderators, indicating, attempte...
# 23424    [important, demographic, attribute, recognitio...
# 33451    [representation, evolutionary, computation, va...
# 12625    [artificial, techniques, constraint, satisfact...
# 5926     [fundamental, estimation, probability, distrib...
#                                ...
# 23410    [rectangle, segmentation, algorithm, backgroun...
# 9090     [algorithm, unlabeled, information, retrieval,...
# 6078     [generalization, associated, asymptotic, unifo...
# 19253    [numerical, uncertainty, representations, evid...
# 12318    [detection, interactions, molecular, particula...
# Name: keywords, Length: 6000, dtype: object

# %% [markdown]
# ### Learning Probability Distributions

# %%
from collections import defaultdict
dictionary = defaultdict(lambda: [0, 0])
for desc, tag in zip(df['keywords'], df['tag']):
    for word in set(desc):
        if tag == 'cs':
            dictionary[word][0] += 1
        else:
            dictionary[word][1] += 1

print("We have a dictionary of", len(dictionary), "words.")

words, counts_cs, counts_stat = [], [], []
for word, count in dictionary.items():
    if count[0] + count[1] > WORD_COUNT_THRESHOLD:
        words.append(word)
        counts_cs.append(count[0])
        counts_stat.append(count[1])
print("Out of those", len(words), f"have over {WORD_COUNT_THRESHOLD} occurances")

fig = pg.Figure([pg.Bar(x=words[:200], y=counts_cs[:200]),
                 pg.Bar(x=words[:200], y=counts_stat[:200])])
fig.update_layout(title_text=f'Some random words and the frequency plot of those with over {WORD_COUNT_THRESHOLD} occurances')
fig.show()
# Out:
# We have a dictionary of 8727 words.
# Out of those 4633 have over 1 occurances
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="f47604f0-f534-4090-aa5c-b22d6f69031e" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("f47604f0-f534-4090-aa5c-b22d6f69031e")) {                    Plotly.newPlot(                        "f47604f0-f534-4090-aa5c-b22d6f69031e",                        [{"x":["indicates","psycholinguistic","classification","decreased","contextual","automatic","challenging","communities","difficult","framework","categories","approaches","indicating","potential","demonstrate","improvement","interaction","indications","attempted","information","performance","highlight","demographic","controlled","challenges","presented","important","representative","exploiting","robustness","attribute","environments","recognition","requesting","minimization","difference","different","representation","computation","polylogarithmic","precisely","proportional","theoretical","independently","inversely","dependence","algorithms","variables","evolutionary","functions","multiplicative","component","optimization","probability","nonlinear","trajectory","effectiveness","satisfaction","stability","dynamical","solutions","techniques","numerical","asymptotic","backpropagation","artificial","illustrate","trajectories","recurrent","measurement","algorithm","constraint","methodology","evaluating","estimation","construct","factorized","introduce","fundamental","characterize","approximately","observations","contraction","partition","characterization","flexibility","generation","distribution","bijective","structure","probabilistic","identical","tractable","simplicity","invertibility","densities","transformation","including","combination","tractability","normalized","dimensional","assumption","classifier","separated","maximally","templates","discriminant","extracting","outperforms","biometric","interpretable","separability","additional","appropriate","experiments","researchers","interpretability","designing","expressed","coefficients","contributes","discriminative","coordinates","modification","criterion","identities","respective","objectives","quadratic","distributed","operation","convergence","conjecture","analogous","sometimes","parameter","alternative","relationships","activation","illustrating","inference","formulated","individual","formulation","resulting","applicability","canonical","classical","structural","naturally","accurately","extensions","variational","demonstrated","straightforward","hierarchical","represents","outperforming","correlation","implementations","statistical","variation","selecting","remarkably","associated","computational","thresholding","correlates","individuals","available","transformed","successful","corrupted","unrelated","obscuring","negatives","selection","remaining","processing","penalized","iterative","multitude","computers","positives","compression","underpinning","competitive","normality","continuous","regression","supercomputing","implementation","collected","penalties","accommodates","association","unfortunately","commodity","simulated"],"y":[27,4,495,5,51,179,273,13,158,530,70,439,17,172,555,176,93,1,6,701,903,28,7,34,118,181,350,38,88,106,38,84,377,3,81,61,727,353,148,2,21,20,166,48,2,19,609,121,61,225,16,86,323,178,66,26,211,13,39,23,162,367,78,17,24,116,75,27,163,35,857,82,67,62,193,92,8,315,73,37,29,77,2,27,28,17,158,218,0,332,162,18,28,26,0,7,40,197,140,9,28,197,67,152,7,8,12,8,56,270,16,28,8,112,82,615,64,31,52,36,30,7,94,17,20,53,10,19,30,27,98,52,121,12,10,27,110,102,65,39,7,202,46,135,89,155,38,18,96,67,64,55,53,56,102,21,100,44,28,72,29,155,58,40,12,111,285,14,5,34,306,20,63,28,3,0,4,143,18,281,7,77,5,22,10,47,1,135,1,96,116,1,122,78,7,2,27,32,4,53],"type":"bar"},{"x":["indicates","psycholinguistic","classification","decreased", ...

# %% [markdown]
# For each word, for both the subjects, we can apply Bayes rule.
#
# $$P\bigg(\frac{\text{subject}}{\text{word}}\bigg) = P\bigg(\frac{\text{word}}{\text{subject}}\bigg) \times \frac{P(\text{subject})}{P(\text{word})}$$

# %% [markdown]
# ### Computing the resultant probabilities

# %%
prior = np.array([train_df["tag"].value_counts()["cs"], train_df["tag"].value_counts()["stat"]]) / len(train_df)
evidence = np.array([counts_cs / train_df["tag"].value_counts()["cs"], counts_stat / train_df["tag"].value_counts()["stat"]]).T
likelihood = (np.array(counts_cs) + np.array(counts_stat)) / len(train_df)

prior.shape, likelihood.shape, evidence.shape
# Out:
# ((2,), (4633,), (4633, 2))

# %%
words_to_index = defaultdict(lambda: -1)
for idx, word in enumerate(words):
    words_to_index[word] = idx

correct, total = 0, 0

answers = []
for tag, keywords in zip(test_df["tag"], test_df["keywords"]):
    this_counts = np.zeros(len(words))
    for word in keywords:
        idx = words_to_index[word]
        if idx != -1:
            this_counts[idx] = 1

    marginal = np.multiply(prior.T, np.divide(
        np.multiply(this_counts.reshape(-1, 1), evidence), likelihood.reshape(-1, 1))) + 0.001
    joint = np.sum(np.log(marginal), axis=0)
    predicted = 'cs' if joint[0] > joint[1] else 'stat'
    answers.append(predicted)
    if predicted == tag:
        correct += 1
    total += 1
test_df.insert(1, "predictions", answers, True)

print("Accuracy:", correct / total)
# Out:
# Accuracy: 0.8191666666666667

# %% [markdown]
# ### Visualizing a few examples

# %%
def explain(example):
    from IPython.display import HTML
    title, desc, answer = example["title"], example["summary"], example["tag"]
    html = ""
    title = re.sub(' +', ' ', re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', title)))
    desc = re.sub(' +', ' ', re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', desc)))
    for text in [title, desc]:
        for word in text.split():
            idx = words_to_index[word.lower()]
            if idx == -1:
                html += f"<span style=''>{word}</span> "
            else:
                posterior = np.multiply(evidence[idx], prior)
                posterior /= np.sum(posterior)
                if posterior[0] > posterior[1] if answer == 'cs' else (posterior[0] <= posterior[1]):
                    color = max(0.3, posterior[0] - posterior[1])
                    html += f"<span style='background-color:rgba(0, 255, 0, {color});'>{word}</span> "
                else:
                    color = max(0.3, posterior[1] - posterior[0])
                    html += f"<span style='background-color:rgba(255, 0, 0, {color});'>{word}</span> "
        html += "<br/><br/>"
    return HTML(html)

# %%
x = test_df[np.logical_and(test_df["predictions"] == test_df["tag"], test_df["tag"] == "cs")].iloc[0]
explain(x)
# Out:
# <span style='background-color:rgba(0, 255, 0, 0.3);'>Algorithms</span> <span style=''>for</span> <span style=''>Image</span> <span style=''>Analysis</span> <span style=''>and</span> <span style='background-color:rgba(0, 255, 0, 0.32075471698113206);'>Combination</span> <span style=''>of</span> <span style=''>Pattern</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Classifiers</span> <span style=''>with</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Application</span> <span style=''>to</span> <span style=''>Medical</span> <span style='background-color:rgba(0, 255, 0, 0.5277777777777777);'>Diagnosis</span> <br/><br/><span style=''>Medical</span> <span style='background-color:rgba(0, 255, 0, 1.0);'>Informatics</span> <span style=''>and</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>application</span> <span style=''>of</span> <span style=''>modern</span> <span style=''>signal</span> <span style='background-color:rgba(0, 255, 0, 0.4373401534526855);'>processing</span> <span style=''>in</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.5);'>assistance</span> <span style=''>of</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>diagnostic</span> <span style=''>process</span> <span style=''>in</span> <span style=''>medical</span> <span style=''>imaging</span> <span style=''>is</span> <span style=''>one</span> <span style=''>of</span> <span style=''>the</span> <span style=''>more</span> <span style=''>recent</span> <span style=''>and</span> <span style=''>active</span> <span style=''>research</span> <span style=''>areas</span> <span style=''>today</span> <span style=''>This</span> <span style=''>thesis</span> <span style='background-color:rgba(0, 255, 0, 0.3258426966292135);'>addresses</span> <span style=''>a</span> <span style=''>variety</span> <span style=''>of</span> <span style=''>issues</span> <span style=''>related</span> <span style=''>to</span> <span style=''>the</span> <span style=''>general</span> <span style=''>problem</span> <span style=''>of</span> <span style=''>medical</span> <span style=''>image</span> <span style=''>analysis</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>specifically</span> <span style=''>in</span> <span style='background-color:rgba(0, 255, 0, 1.0);'>mammography</span> <span style=''>and</span> <span style=''>presents</span> <span style=''>a</span> <span style=''>series</span> <span style=''>of</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>algorithms</span> <span style=''>and</span> <span style=''>design</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>approaches</span> <span style=''>for</span> <span style=''>all</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.6326530612244898);'>intermediate</span> <span style=''>levels</span> <span style=''>of</span> <span style=''>a</span> <span style=''>modern</span> <span style=''>system</span> <span style=''>for</span> <span style=''>computer</span> <span style=''>aided</span> <span style='background-color:rgba(0, 255, 0, 0.5277777777777777);'>diagnosis</span> <span style=''>(CAD)</span> <span style=''>The</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>diagnostic</span> <span style=''>problem</span> <span style=''>is</span> <span style=''>analyzed</span> <span style=''>with</span> <span style=''>a</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>systematic</span> <span style=''>approach</span> <span style=''>first</span> <span style=''>defining</span> <span style=''>the</span> <span style=''>imaging</span> <span style='background-color:rgba(0, 255, 0, 0.4330708661417324);'>characteristics</span> <span style=''>and</span> <span style=''>features</span> <span style=''>that</span> <span style=''>are</span> <span style=''>relevant</span> <span style=''>to</span> <span style=''>probable</span> <span style='background-color:rgba(0, 255, 0, 0.5);'>pa ...

# %%
x = test_df[np.logical_and(test_df["predictions"] == test_df["tag"], test_df["tag"] == "stat")].iloc[0]
explain(x)
# Out:
# <span style='background-color:rgba(0, 255, 0, 0.3);'>Multiresolution</span> <span style=''>Tensor</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Decomposition</span> <span style=''>for</span> <span style=''>Multiple</span> <span style=''>Spatial</span> <span style=''>Passing</span> <span style=''>Networks</span> <br/><br/><span style=''>This</span> <span style=''>article</span> <span style=''>is</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>motivated</span> <span style=''>by</span> <span style=''>soccer</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>positional</span> <span style=''>passing</span> <span style=''>networks</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>collected</span> <span style=''>across</span> <span style=''>multiple</span> <span style=''>games</span> <span style=''>We</span> <span style=''>refer</span> <span style=''>to</span> <span style=''>these</span> <span style=''>data</span> <span style=''>as</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>replicated</span> <span style=''>spatial</span> <span style=''>passing</span> <span style=''>networks</span> <span style=''>to</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>accurately</span> <span style=''>model</span> <span style=''>such</span> <span style=''>data</span> <span style=''>it</span> <span style=''>is</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>necessary</span> <span style=''>to</span> <span style=''>take</span> <span style=''>into</span> <span style=''>account</span> <span style=''>the</span> <span style=''>spatial</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>positions</span> <span style=''>of</span> <span style=''>the</span> <span style=''>passer</span> <span style=''>and</span> <span style=''>receiver</span> <span style=''>for</span> <span style=''>each</span> <span style=''>passing</span> <span style=''>event</span> <span style=''>This</span> <span style=''>spatial</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>registration</span> <span style=''>and</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>replicates</span> <span style=''>that</span> <span style=''>occur</span> <span style=''>across</span> <span style=''>games</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>represent</span> <span style=''>key</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>differences</span> <span style=''>with</span> <span style=''>usual</span> <span style=''>social</span> <span style=''>network</span> <span style=''>data</span> <span style=''>As</span> <span style=''>a</span> <span style=''>key</span> <span style=''>step</span> <span style=''>before</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>investigating</span> <span style=''>how</span> <span style=''>the</span> <span style=''>passing</span> <span style=''>dynamics</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>influence</span> <span style=''>team</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>performance</span> <span style=''>we</span> <span style=''>focus</span> <span style=''>on</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>developing</span> <span style=''>methods</span> <span style=''>for</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>summarizing</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>different</span> <span style=''>teams</span> <span style=''>passing</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>strategies</span> <span style=''>Our</span> <span style=''>proposed</span> <span style=''>approach</span> <span style=''>relies</span> <span style=''>on</span> <span style=''>a</span> <span style=''>novel</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>multiresolution</span> <span style=''>data</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>representation</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>framework</span> <span style=' ...

# %%
x = test_df[np.logical_and(test_df["predictions"] != test_df["tag"], test_df["tag"] == "cs")].iloc[0]
explain(x)
# Out:
# <span style=''>A</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Tractable</span> <span style=''>POMDP</span> <span style=''>for</span> <span style=''>a</span> <span style=''>Class</span> <span style=''>of</span> <span style='background-color:rgba(0, 255, 0, 0.4285714285714286);'>Sequencing</span> <span style=''>Problems</span> <br/><br/><span style=''>We</span> <span style=''>consider</span> <span style=''>a</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>partially</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>observable</span> <span style=''>Markov</span> <span style=''>decision</span> <span style=''>problem</span> <span style=''>(POMDP)</span> <span style=''>that</span> <span style=''>models</span> <span style=''>a</span> <span style=''>class</span> <span style=''>of</span> <span style='background-color:rgba(0, 255, 0, 0.4285714285714286);'>sequencing</span> <span style=''>problems</span> <span style=''>Although</span> <span style=''>POMDPs</span> <span style=''>are</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>typically</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>intractable</span> <span style=''>our</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>formulation</span> <span style=''>admits</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>tractable</span> <span style=''>solution</span> <span style=''>Instead</span> <span style=''>of</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>maintaining</span> <span style=''>a</span> <span style=''>value</span> <span style=''>function</span> <span style=''>over</span> <span style=''>a</span> <span style=''>high</span> <span style='background-color:rgba(255, 0, 0, 0.30388692579505294);'>dimensional</span> <span style=''>set</span> <span style=''>of</span> <span style=''>belief</span> <span style=''>states</span> <span style=''>we</span> <span style=''>reduce</span> <span style=''>the</span> <span style=''>state</span> <span style=''>space</span> <span style=''>to</span> <span style=''>one</span> <span style=''>of</span> <span style=''>smaller</span> <span style='background-color:rgba(255, 0, 0, 0.36792452830188666);'>dimension</span> <span style=''>in</span> <span style=''>which</span> <span style=''>grid</span> <span style=''>based</span> <span style=''>dynamic</span> <span style='background-color:rgba(0, 255, 0, 0.39354838709677414);'>programming</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>techniques</span> <span style=''>are</span> <span style='background-color:rgba(0, 255, 0, 0.3472584856396867);'>effective</span> <span style=''>We</span> <span style=''>develop</span> <span style=''>an</span> <span style=''>error</span> <span style=''>bound</span> <span style=''>for</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>resulting</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>approximation</span> <span style=''>and</span> <span style=''>discuss</span> <span style=''>an</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>application</span> <span style=''>of</span> <span style=''>the</span> <span style=''>model</span> <span style=''>to</span> <span style=''>a</span> <span style=''>problem</span> <span style=''>in</span> <span style=''>targeted</span> <span style='background-color:rgba(255, 0, 0, 0.5294117647058822);'>advertising</span> <br/><br/>

# %%
x = test_df[np.logical_and(test_df["predictions"] != test_df["tag"], test_df["tag"] == "stat")].iloc[0]
explain(x)
# Out:
# <span style=''>Bayesian</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>nonparametric</span> <span style=''>image</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>segmentation</span> <span style=''>using</span> <span style=''>a</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>generalized</span> <span style=''>Swendsen</span> <span style=''>Wang</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>algorithm</span> <br/><br/><span style='background-color:rgba(255, 0, 0, 0.3);'>Unsupervised</span> <span style=''>image</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>segmentation</span> <span style=''>aims</span> <span style=''>at</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>clustering</span> <span style=''>the</span> <span style=''>set</span> <span style=''>of</span> <span style=''>pixels</span> <span style=''>of</span> <span style=''>an</span> <span style=''>image</span> <span style=''>into</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>spatially</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>homogeneous</span> <span style=''>regions</span> <span style=''>We</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>introduce</span> <span style=''>here</span> <span style=''>a</span> <span style=''>class</span> <span style=''>of</span> <span style=''>Bayesian</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>nonparametric</span> <span style=''>models</span> <span style=''>to</span> <span style=''>address</span> <span style=''>this</span> <span style=''>problem</span> <span style=''>These</span> <span style=''>models</span> <span style=''>are</span> <span style=''>based</span> <span style=''>on</span> <span style=''>a</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>combination</span> <span style=''>of</span> <span style=''>a</span> <span style=''>Potts</span> <span style=''>like</span> <span style=''>spatial</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>smoothness</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>component</span> <span style=''>and</span> <span style=''>a</span> <span style=''>prior</span> <span style=''>on</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>partitions</span> <span style=''>which</span> <span style=''>is</span> <span style=''>used</span> <span style=''>to</span> <span style=''>control</span> <span style=''>both</span> <span style=''>the</span> <span style=''>number</span> <span style=''>and</span> <span style=''>size</span> <span style=''>of</span> <span style=''>clusters</span> <span style=''>This</span> <span style=''>class</span> <span style=''>of</span> <span style=''>models</span> <span style=''>is</span> <span style=''>flexible</span> <span style=''>enough</span> <span style=''>to</span> <span style=''>include</span> <span style=''>the</span> <span style=''>standard</span> <span style=''>Potts</span> <span style=''>model</span> <span style=''>and</span> <span style=''>the</span> <span style=''>more</span> <span style=''>recent</span> <span style=''>Potts</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Dirichlet</span> <span style=''>Process</span> <span style=''>model</span> <span style=''>citeOrbanz2008</span> <span style=''>More</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>importantly</span> <span style=''>any</span> <span style=''>prior</span> <span style=''>on</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>partitions</span> <span style=''>can</span> <span style=''>be</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>introduced</span> <span style=''>to</span> <span style=''>control</span> <span style=''>the</span> <span style=''>global</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>clustering</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>structure</span> <span style=''>so</span> <span style=''>that</span> <span style=''>it</span> <span style=''>is</span> <span style=' ...

# %% [markdown]
# ### Visualizing the Learnt Words

# %%
print("Some Computer Science words are:")
for word_cs in np.argsort(evidence[:, 0] - evidence[:, 1])[-10:]:
    print(f"\t{words[word_cs]} ({evidence[word_cs, 0]})")
print()
print("Some Statistics words are:")
for word_st in np.argsort(evidence[:, 1] - evidence[:, 0])[-10:]:
    print(f"\t{words[word_st]} ({evidence[word_st, 1]})")
# Out:
# Some Computer Science words are:
# 	processing (0.10107913669064748)
# 	knowledge (0.1237410071942446)
# 	architecture (0.0856115107913669)
# 	segmentation (0.07050359712230216)
# 	experimental (0.13741007194244603)
# 	information (0.252158273381295)
# 	different (0.26151079136690647)
# 	detection (0.1251798561151079)
# 	recognition (0.1356115107913669)
# 	convolutional (0.14064748201438848)
#
# Some Statistics words are:
# 	parameter (0.11633663366336634)
# 	stochastic (0.12821782178217822)
# 	theoretical (0.15346534653465346)
# 	estimation (0.16386138613861387)
# 	variables (0.14405940594059405)
# 	statistical (0.15693069306930693)
# 	dimensional (0.18267326732673267)
# 	distribution (0.19653465346534654)
# 	inference (0.19554455445544555)
# 	regression (0.17524752475247524)

# %% [markdown]
# ## Probability Smoothing
#
# Probability smoothing is a language modeling technique that assigns some non-zero probability to events that were unseen in the training data. This has the effect that the probability mass is divided over more events, hence the probability distribution becomes more smooth.

# %% [markdown]
# ### Realizing the Problem

# %%
posterior = np.multiply(np.divide(evidence, np.reshape(likelihood, (-1, 1))), np.reshape(prior, (1, -1)))

fig = pg.Figure([pg.Bar(x=words, y=evidence[:20, 0]),
                 pg.Bar(x=words, y=posterior[:20, 0])])
fig.update_layout(title_text='Evidence and Posterior for each word')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="393b38d9-b44e-4a93-a94b-d0a02fcaba45" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("393b38d9-b44e-4a93-a94b-d0a02fcaba45")) {                    Plotly.newPlot(                        "393b38d9-b44e-4a93-a94b-d0a02fcaba45",                        [{"x":["indicates","psycholinguistic","classification","decreased","contextual","automatic","challenging","communities","difficult","framework","categories","approaches","indicating","potential","demonstrate","improvement","interaction","indications","attempted","information","performance","highlight","demographic","controlled","challenges","presented","important","representative","exploiting","robustness","attribute","environments","recognition","requesting","minimization","difference","different","representation","computation","polylogarithmic","precisely","proportional","theoretical","independently","inversely","dependence","algorithms","variables","evolutionary","functions","multiplicative","component","optimization","probability","nonlinear","trajectory","effectiveness","satisfaction","stability","dynamical","solutions","techniques","numerical","asymptotic","backpropagation","artificial","illustrate","trajectories","recurrent","measurement","algorithm","constraint","methodology","evaluating","estimation","construct","factorized","introduce","fundamental","characterize","approximately","observations","contraction","partition","characterization","flexibility","generation","distribution","bijective","structure","probabilistic","identical","tractable","simplicity","invertibility","densities","transformation","including","combination","tractability","normalized","dimensional","assumption","classifier","separated","maximally","templates","discriminant","extracting","outperforms","biometric","interpretable","separability","additional","appropriate","experiments","researchers","interpretability","designing","expressed","coefficients","contributes","discriminative","coordinates","modification","criterion","identities","respective","objectives","quadratic","distributed","operation","convergence","conjecture","analogous","sometimes","parameter","alternative","relationships","activation","illustrating","inference","formulated","individual","formulation","resulting","applicability","canonical","classical","structural","naturally","accurately","extensions","variational","demonstrated","straightforward","hierarchical","represents","outperforming","correlation","implementations","statistical","variation","selecting","remarkably","associated","computational","thresholding","correlates","individuals","available","transformed","successful","corrupted","unrelated","obscuring","negatives","selection","remaining","processing","penalized","iterative","multitude","computers","positives","compression","underpinning","competitive","normality","continuous","regression","supercomputing","implementation","collected","penalties","accommodates","association","unfortunately","commodity","simulated","introduces","nucleotide","prediction","disparate","inability","hypergraphs","interacts","unlabeled","hypergraph","enumeration","generalization","instances","biological","methodologies","relational","formulate","supervised","extensively","represent","analytics","dimensionality","massively","properties","informally","attributes","partitioning","situation","efficient","perspectives","summarizing","dimensions","observation","mathematically","clustering","multivariate","establish","equivalent","published","constructing","posteriors","auxiliary","generative","equivalence","generated","according","subsequent","distributions","segmentation","perceptually","superpixel","preprocessing","assigning","coherence","diffe ...

# %%
print("Some words which never appear in Computer Science paper:\n\t" + "\n\t".join([words[idx] for idx in np.where(np.array(counts_cs) == 0)[0][:20]]))
print("Some words which never appear in Statistics papers:\n\t" + "\n\t".join([words[idx] for idx in np.where(np.array(counts_stat) == 0)[0][:20]]))
# Out:
# Some words which never appear in Computer Science paper:
# 	bijective
# 	invertibility
# 	obscuring
# 	informally
# 	profitable
# 	psychiatric
# 	schizophrenia
# 	multipartite
# 	tightening
# 	resampled
# 	unavoidably
# 	nonparanormal
# 	compounded
# 	econometrics
# 	eigenspaces
# 	interpolations
# 	underestimation
# 	prioritize
# 	transports
# 	straightforwardly
# Some words which never appear in Statistics papers:
# 	psycholinguistic
# 	requesting
# 	polylogarithmic
# 	superpixel
# 	continues
# 	september
# 	calibrates
# 	substitutes
# 	eligibility
# 	recommenders
# 	interoperability
# 	reflection
# 	outputting
# 	fingerprint
# 	pheromone
# 	discourse
# 	transitioning
# 	underwater
# 	curiosity
# 	programmed

# %% [markdown]
# Notice the fact that there are cases where the Evidence $P\big(\frac{\text{word}}{\text{subject}}\big) \rightarrow 0$. This is because there are occurances of the given word in the corpus (all the abstract of papers put together) of that subject.
#
# However, this is no way implies that if a word (eg. Employment) never occurs in our training corpus in a Computer Science paper, it will also never occur in a paper in the test set.
#
# Therefore, setting $P(\text{word} | \text{subject}) = 0$ is incorrect, since it will make the posterior $P(\text{subject} | \text{word}) = 0$, even if the corresponding count it 0, we need to come up with a smoother formulation of the Evidence variables.

# %% [markdown]
# ### Laplace Smoothing
#
#
#
# https://towardsdatascience.com/laplace-smoothing-in-na%C3%AFve-bayes-algorithm-9c237a8bdece

# %%
alpha = 0.1
counts_cs, counts_stat = np.array(counts_cs), np.array(counts_stat)
evidence_smooth = np.array([(counts_cs + alpha) / (train_df["tag"].value_counts()["cs"] + alpha * len(words)),
                            (counts_stat + alpha) / (train_df["tag"].value_counts()["stat"] + alpha * len(words))]).T
print(np.min(evidence_smooth))
sns.displot(evidence_smooth)
# Out:
# 3.0832793759442546e-05

# %%
words_to_index = defaultdict(lambda: -1)
for idx, word in enumerate(words):
    words_to_index[word] = idx

correct, total = 0, 0

answers = []
for tag, keywords in zip(test_df["tag"], test_df["keywords"]):
    this_counts = np.zeros(len(words))
    for word in keywords:
        idx = words_to_index[word]
        if idx != -1:
            this_counts[idx] = 1

    marginal = np.multiply(prior.T, np.divide(np.multiply(this_counts.reshape(-1, 1), evidence_smooth), likelihood.reshape(-1, 1))) + 0.0000001
    joint = np.sum(np.log(marginal), axis=0)
    predicted = 'cs' if joint[0] > joint[1] else 'stat'
    answers.append(predicted)
    if predicted == tag:
        correct += 1
    total += 1
test_df.insert(1, "predictions", answers, True)

print("Accuracy:", correct / total)
# Out:
# Accuracy: 0.7708333333333334
